# %% [markdown]
# # 2. Collocatie - het tellen van woorden in de buurt van een term
# Net als bij een concordantie richt een collocatie-analyse zich op de context van specifieke zoektermen. Het verschil is dat bij een collocatie-analyse alle woorden in de context worden geteld. Op deze manier kan er een beeld ontstaan van de woorden die veel in de omgeving van een specifieke zoekterm worden gebruikt.
#
# In de code hieronder verwijst `search_term` weer naat de term waarnaar wordt gezocht, en `window` bepaalt weer het aantal woorden voor en na de opgegeven zoekterm.
#
# In de onderstaande code wordt ook de functie 'removeStopwords()' gebruikt. Deze functie heeft als effect dat de woorden die in alle documenten gemiddeld genomen even vaak voorkomen (bv. de, het, een wij, zijn, hebben, geweest, allen, doen, ik, jullie, etc.) en dus niet onderscheidend zijn voor een bepaald document, verwijderd worden.
#
# De onderstaande code zoekt in het gehele corpus, dat uit ca. 600 egodocumenten bestaat, en het uitvoeren van de code kan daarom enige tijd in beslag nemen.

# %%
import os
from os.path import join
import re
import pandas as pd
from kitlvTdm import *

# %%
import os
from os.path import join
import re
import pandas as pd
from kitlvTdm import *

# Maak drie variabelen, de dir (directory/map) corpus, de zoekterm 'baboe', en de search window: 30/

path = 'Corpus'
searchTerm = 'joden'
window = 30

# Maak een dictionary corpusFreq (een variabele die werkt in de vorm {key : value, key : value})
corpusFreq = dict()

# Voor ieder bestand in de map in de variabele dir ('corpus')
for file in os.listdir( path ):
    
    # Als het bestand een tekst bestand is:
    if re.search( '[.]txt$' , file ):
        print("Reading {}  ...".format( file ))   
        # Vind de frequencies van alle woorden die voorkomen in de buurt van de zoekterm. Sla ze op in de variabele freq
        # "In de buurt" wordt dus aangegeven door de variabele 'window'
        freq = collocation( join( path , file ) , searchTerm , window )
        
        # Verwijder de stopwoorden uit de gevonden collocaties 
        freq = removeStopwords( freq )

        # Voeg de gevonden collocaties zonder stopwoorden toe aan de variabele corpusFreq.
        corpusFreq.update(freq)
        
        # Het aantal collocaties dat je wilt laten zien
        max = 30

        # De teller die bijhoudt hoeveel collocaties er zijn getoond.
        i = 0

        # Als er collocaties zijn gevonden:
        if len(corpusFreq)> 0:
            
            # Sorteer de collocaties van hoog naar laag. "key = lambda x: corpusFreq[x]" is nodig voor het juist sorteren aangezien de
            # frequenties opgeslagen zijn in een dictionary (een data type). "reverse = True" zorgt ervoor het van hoog naar laag 
            # is gesorteerd (ipv de automatische laag naar hoog).
            corpusFreqSorted = sorted(corpusFreq, key = lambda x: corpusFreq[x], reverse = True)
            
            print( f'The following words are used most frequently in the vicinity of "{ searchTerm }": \n' )

            # Print het volgendende waarbij searchTerm de eerder gedefinieerde zoekterm is

            for f in corpusFreqSorted:
                i += 1
                
                # Voor iedere collocatie in de van hoog naar laag gesorteerde frequenties
                # Teller plus 1
                # Laat het woord en de frequentie zien waarmee het voorkomt in de buurt van de zoekterm
                print( '{} =>  {}'.format( f , corpusFreq[f] ) )
   
              
      
                # Als er "max" (hierboven gedefinieerd) collocatie frequenties zijn getoond:
                # Stop met laten zien
                if i == max: 
                    break
# Out:
# Reading 03391.txt  ...
# Cannot read the list of stopwords!
# Reading 03392.txt  ...
# Cannot read the list of stopwords!
# Reading 03393.txt  ...
# Cannot read the list of stopwords!
# Reading 03394.txt  ...
# Cannot read the list of stopwords!
# Reading 03395.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  9
# uit =>  2
# het =>  2
# overijssel =>  2
# en =>  2
# in =>  2
# charles =>  1
# destree =>  1
# d =>  1
# klaver =>  1
# jan =>  1
# koster =>  1
# s.m =>  1
# pos =>  1
# barend =>  1
# weert =>  1
# verder =>  1
# waren =>  1
# er =>  1
# stoters =>  1
# oosten =>  1
# van =>  1
# nederland =>  1
# achterhoek =>  1
# veluwe =>  1
# eerste =>  1
# jodendeportaties =>  1
# gleichschaltung =>  1
# maakten =>  1
# twentenaren =>  1
# Reading 03396.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  9
# uit =>  2
# het =>  2
# overijssel =>  2
# en =>  2
# in =>  2
# charles =>  1
# destree =>  1
# d =>  1
# klaver =>  1
# jan =>  1
# koster =>  1
# s.m =>  1
# pos =>  1
# barend =>  1
# weert =>  1
# verder =>  1
# waren =>  1
# er =>  1
# stoters =>  1
# oosten =>  1
# van =>  1
# nederland =>  1
# achterhoek =>  1
# veluwe =>  1
# eerste =>  1
# jodendeportaties =>  1
# gleichschaltung =>  1
# maakten =>  1
# twentenaren =>  1
# Reading 03398.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  9
# uit =>  2
# het =>  2
# overijssel =>  2
# en =>  2
# in =>  2
# charles =>  1
# destree =>  1
# d =>  1
# klaver =>  1
# jan =>  1
# koster =>  1
# s.m =>  1
# pos =>  1
# barend =>  1
# weert =>  1
# verder =>  1
# waren =>  1
# er =>  1
# stoters =>  1
# oosten =>  1
# van =>  1
# nederland =>  1
# achterhoek =>  1
# veluwe =>  1
# eerste =>  1
# jodendeportaties =>  1
# gleichschaltung =>  1
# maakten =>  1
# twentenaren =>  1
# Reading 03399.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  40
# van =>  25
# het =>  20
# in =>  17
# een =>  17
# en =>  16
# op =>  10
# die =>  10
# dat =>  9
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# tegen =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# Reading 03400.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  40
# van =>  25
# het =>  20
# in =>  17
# een =>  17
# en =>  16
# op =>  10
# die =>  10
# dat =>  9
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# tegen =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# Reading 03401.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  40
# van =>  25
# het =>  20
# in =>  17
# een =>  17
# en =>  16
# op =>  10
# die =>  10
# dat =>  9
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# tegen =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# Reading 03402.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  40
# van =>  25
# het =>  20
# in =>  17
# een =>  17
# en =>  16
# op =>  10
# die =>  10
# dat =>  9
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# tegen =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# Reading 03403.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  40
# van =>  25
# het =>  20
# in =>  17
# een =>  17
# en =>  16
# op =>  10
# die =>  10
# dat =>  9
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# tegen =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# Reading 03404.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# die =>  10
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# de =>  5
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# door =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# zich =>  3
# geen =>  3
# mij =>  3
# Reading 03405.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# die =>  10
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# de =>  5
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# door =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# zich =>  3
# geen =>  3
# mij =>  3
# Reading 03406.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# die =>  10
# te =>  7
# was =>  6
# zijn =>  6
# aan =>  6
# joodse =>  6
# de =>  5
# wij =>  5
# dit =>  5
# alle =>  5
# uit =>  4
# bij =>  4
# ons =>  4
# deze =>  4
# meer =>  4
# ondergang =>  4
# waren =>  3
# door =>  3
# voor =>  3
# kwam =>  3
# toen =>  3
# ook =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# zich =>  3
# geen =>  3
# mij =>  3
# Reading 03407.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  16
# en =>  11
# dat =>  11
# van =>  9
# in =>  7
# een =>  7
# ik =>  7
# het =>  6
# joodse =>  6
# over =>  6
# er =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# niet =>  4
# meer =>  4
# ondergang =>  4
# werd =>  3
# door =>  3
# kwam =>  3
# bij =>  3
# op =>  3
# ook =>  3
# die =>  3
# maatregelen =>  3
# duitse =>  3
# met =>  3
# dr =>  3
# mijn =>  3
# aan =>  3
# Reading 03408.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  16
# en =>  11
# dat =>  11
# van =>  9
# in =>  7
# een =>  7
# ik =>  7
# het =>  6
# joodse =>  6
# over =>  6
# er =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# niet =>  4
# meer =>  4
# ondergang =>  4
# werd =>  3
# door =>  3
# kwam =>  3
# bij =>  3
# op =>  3
# ook =>  3
# die =>  3
# maatregelen =>  3
# duitse =>  3
# met =>  3
# dr =>  3
# mijn =>  3
# aan =>  3
# Reading 03409.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  16
# en =>  11
# dat =>  11
# van =>  9
# in =>  7
# een =>  7
# ik =>  7
# het =>  6
# joodse =>  6
# over =>  6
# er =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# niet =>  4
# meer =>  4
# ondergang =>  4
# werd =>  3
# door =>  3
# kwam =>  3
# bij =>  3
# op =>  3
# ook =>  3
# die =>  3
# maatregelen =>  3
# duitse =>  3
# met =>  3
# dr =>  3
# mijn =>  3
# aan =>  3
# Reading 03410.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# dat =>  11
# een =>  7
# ik =>  7
# het =>  6
# joodse =>  6
# over =>  6
# er =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# en =>  3
# werd =>  3
# kwam =>  3
# bij =>  3
# op =>  3
# maatregelen =>  3
# duitse =>  3
# met =>  3
# dr =>  3
# mijn =>  3
# aan =>  3
# moesten =>  3
# zich =>  3
# geen =>  3
# te =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# Reading 03411.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# dat =>  11
# een =>  7
# ik =>  7
# het =>  6
# joodse =>  6
# over =>  6
# er =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# en =>  3
# werd =>  3
# kwam =>  3
# bij =>  3
# op =>  3
# maatregelen =>  3
# duitse =>  3
# met =>  3
# dr =>  3
# mijn =>  3
# aan =>  3
# moesten =>  3
# zich =>  3
# geen =>  3
# te =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# Reading 03412.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# dat =>  11
# een =>  7
# ik =>  7
# het =>  6
# joodse =>  6
# over =>  6
# er =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# en =>  3
# werd =>  3
# kwam =>  3
# bij =>  3
# op =>  3
# maatregelen =>  3
# duitse =>  3
# met =>  3
# dr =>  3
# mijn =>  3
# aan =>  3
# moesten =>  3
# zich =>  3
# geen =>  3
# te =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# Reading 03413.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03414.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03415.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03416.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03417.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03418.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03419.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03420.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03421.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03422.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03423.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03424.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03425.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03426.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03427.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03428.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03429.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03430.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  17
# van =>  9
# en =>  8
# in =>  8
# het =>  7
# ik =>  7
# een =>  6
# over =>  6
# er =>  5
# uit =>  5
# op =>  5
# wij =>  5
# dit =>  5
# ons =>  4
# meer =>  4
# ondergang =>  4
# palestina =>  4
# immigratie =>  4
# kwam =>  3
# tegen =>  3
# maatregelen =>  3
# duitse =>  3
# dr =>  3
# mijn =>  3
# moesten =>  3
# oorlog =>  3
# 1965 =>  3
# gestoten =>  3
# werkelijke =>  3
# jodenvervolging =>  3
# Reading 03431.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# in =>  70
# van =>  51
# het =>  46
# en =>  44
# uit =>  28
# werden =>  23
# een =>  22
# dat =>  19
# die =>  19
# aan =>  16
# op =>  15
# ik =>  15
# naar =>  15
# nederland =>  12
# met =>  12
# te =>  12
# was =>  11
# werd =>  11
# voor =>  11
# ook =>  11
# er =>  10
# niet =>  10
# waren =>  9
# joodse =>  9
# meer =>  9
# al =>  9
# kamp =>  9
# we =>  9
# daar =>  8
# Reading 03432.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# in =>  70
# van =>  51
# het =>  46
# en =>  44
# uit =>  28
# werden =>  23
# een =>  22
# dat =>  19
# die =>  19
# aan =>  16
# op =>  15
# ik =>  15
# naar =>  15
# nederland =>  12
# met =>  12
# te =>  12
# was =>  11
# werd =>  11
# voor =>  11
# ook =>  11
# er =>  10
# niet =>  10
# waren =>  9
# joodse =>  9
# meer =>  9
# al =>  9
# kamp =>  9
# we =>  9
# daar =>  8
# Reading 03433.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# in =>  70
# van =>  51
# het =>  46
# en =>  44
# uit =>  28
# werden =>  23
# een =>  22
# dat =>  19
# die =>  19
# aan =>  16
# op =>  15
# ik =>  15
# naar =>  15
# nederland =>  12
# met =>  12
# te =>  12
# was =>  11
# werd =>  11
# voor =>  11
# ook =>  11
# er =>  10
# niet =>  10
# waren =>  9
# joodse =>  9
# meer =>  9
# al =>  9
# kamp =>  9
# we =>  9
# daar =>  8
# Reading 03434.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# in =>  70
# van =>  51
# het =>  46
# en =>  44
# uit =>  28
# werden =>  23
# een =>  22
# dat =>  19
# die =>  19
# aan =>  16
# op =>  15
# ik =>  15
# naar =>  15
# nederland =>  12
# met =>  12
# te =>  12
# was =>  11
# werd =>  11
# voor =>  11
# ook =>  11
# er =>  10
# niet =>  10
# waren =>  9
# joodse =>  9
# meer =>  9
# al =>  9
# kamp =>  9
# we =>  9
# daar =>  8
# Reading 03435.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# van =>  51
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# Reading 03436.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# van =>  51
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# Reading 03437.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# van =>  51
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# Reading 03438.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# van =>  51
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# Reading 03439.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# van =>  51
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# Reading 03440.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  122
# van =>  51
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# Reading 03441.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# met =>  12
# werd =>  11
# voor =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# hen =>  6
# Reading 03442.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03443.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03444.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03445.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03446.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03447.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03448.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03449.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03450.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03451.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# uit =>  28
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# we =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# Reading 03452.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# van =>  6
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# Reading 03453.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# van =>  6
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# Reading 03454.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# van =>  6
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# Reading 03455.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# van =>  6
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# Reading 03456.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# naar =>  15
# nederland =>  12
# werd =>  11
# ook =>  11
# niet =>  10
# do =>  10
# joodse =>  9
# al =>  9
# kamp =>  9
# verzet =>  7
# zijn =>  7
# tegen =>  7
# of =>  7
# tot =>  7
# duitsland =>  7
# enkele =>  7
# van =>  6
# kwam =>  6
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# dit =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# Reading 03457.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# nederland =>  12
# werd =>  11
# ook =>  11
# do =>  10
# joodse =>  9
# kamp =>  9
# de =>  7
# verzet =>  7
# zijn =>  7
# of =>  7
# duitsland =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# het =>  5
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# Reading 03458.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# nederland =>  12
# werd =>  11
# ook =>  11
# do =>  10
# joodse =>  9
# kamp =>  9
# de =>  7
# verzet =>  7
# zijn =>  7
# of =>  7
# duitsland =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# het =>  5
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# Reading 03459.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# nederland =>  12
# werd =>  11
# ook =>  11
# do =>  10
# joodse =>  9
# kamp =>  9
# de =>  7
# verzet =>  7
# zijn =>  7
# of =>  7
# duitsland =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# het =>  5
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# Reading 03460.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# nederland =>  12
# werd =>  11
# ook =>  11
# do =>  10
# joodse =>  9
# kamp =>  9
# de =>  7
# verzet =>  7
# zijn =>  7
# of =>  7
# duitsland =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# mijn =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# het =>  5
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# Reading 03461.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  10
# do =>  10
# joodse =>  9
# kamp =>  9
# zijn =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# Reading 03462.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  10
# do =>  10
# joodse =>  9
# kamp =>  9
# zijn =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# Reading 03463.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  10
# do =>  10
# joodse =>  9
# kamp =>  9
# zijn =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# Reading 03464.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  10
# do =>  10
# joodse =>  9
# kamp =>  9
# zijn =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# Reading 03465.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  10
# do =>  10
# joodse =>  9
# kamp =>  9
# zijn =>  7
# enkele =>  7
# bij =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# kinderen =>  6
# westerbork =>  6
# wel =>  6
# onder =>  6
# openbare =>  6
# amsterdam =>  6
# sobibor =>  6
# als =>  5
# woonden =>  5
# auschwitz =>  5
# vermoord =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# Reading 03466.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03467.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03468.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03469.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03470.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03471.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03472.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03473.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03474.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  15
# do =>  10
# joodse =>  9
# in =>  7
# voor =>  7
# enkele =>  7
# van =>  6
# en =>  6
# maatregelen =>  6
# nog =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# het =>  4
# was =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# Reading 03475.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# en =>  14
# de =>  12
# het =>  10
# do =>  10
# ook =>  7
# is =>  7
# dat =>  6
# maatregelen =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# in =>  5
# een =>  5
# hij =>  5
# te =>  5
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# werd =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# al =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# Reading 03476.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# het =>  10
# do =>  10
# ook =>  7
# is =>  7
# dat =>  6
# maatregelen =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# te =>  5
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# werd =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# al =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# wachten =>  4
# hollandsche =>  4
# gesteld =>  4
# Reading 03477.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# het =>  10
# do =>  10
# ook =>  7
# is =>  7
# dat =>  6
# maatregelen =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# te =>  5
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# werd =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# al =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# wachten =>  4
# hollandsche =>  4
# gesteld =>  4
# Reading 03478.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# het =>  10
# do =>  10
# ook =>  7
# is =>  7
# dat =>  6
# maatregelen =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# te =>  5
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# werd =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# al =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# wachten =>  4
# hollandsche =>  4
# gesteld =>  4
# Reading 03479.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# het =>  10
# do =>  10
# ook =>  7
# is =>  7
# dat =>  6
# maatregelen =>  6
# zoals =>  6
# westerbork =>  6
# wel =>  6
# openbare =>  6
# sobibor =>  6
# te =>  5
# woonden =>  5
# auschwitz =>  5
# crèche =>  5
# schouwburg =>  5
# indië =>  5
# werd =>  4
# ondergang =>  4
# leven =>  4
# tijd =>  4
# al =>  4
# immigratie =>  4
# ongeveer =>  4
# monument =>  4
# zigeuners =>  4
# vanuit =>  4
# wachten =>  4
# hollandsche =>  4
# gesteld =>  4
# Reading 03480.txt  ...
# Cannot read the list of stopwords!
# The following words are used most frequently in the vicinity of "joden":
#
# de =>  107
# en =>  62
# het =>  35
# ze =>  29
# van =>  22
# een =>  22
# te =>  22
# hun =>  20
# niet =>  19
# als =>  17
# is =>  16
# maar =>  15
# er =>  13
# in =>  13
# zij =>  13
# met =>  13
# of =>  13
# dan =>  13
# wat =>  13
# dat =>  11
# zijn =>  11
# ook =>  11
# om =>  11
# land =>  11
# wereld =>  11
# voor =>  10
# die =>  10
# hebben =>  10
# do =>  10
# op =>  9
# Reading 03482.txt  ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_3392/1727180418.py in <module>
#      22         # Vind de frequencies van alle woorden die voorkomen in de buurt van de zoekterm. Sla ze op in de variabele freq
#      23         # "In de buurt" wordt dus aangegeven door de variabele 'window'
# ---> 24         freq = collocation( join( path , file ) , searchTerm , window )
#      25
#      26         # Verwijder de stopwoorden uit de gevonden collocaties
#
# ~\Documents\Niels\projectjes\Stef\kitlvTdm.py in collocation(book, searchTerm, distance)
#     193             i = 0
#     194             for w in words:
# --> 195                 if re.search( regex , w , re.IGNORECASE ):
#     196
#     197                     for x in range( i - distance , i + distance ):
#
# ~\anaconda3\lib\re.py in search(pattern, string, flags)
#     183     """Scan through string looking for a match to the pattern, returning
#     184     a Match object, or None if no match was found."""
# --> 185     return _compile(pattern, flags).search(string)
#     186
#     187 def sub(pattern, repl, string, count=0, flags=0):
#
# ~\anaconda3\lib\re.py in _compile(pattern, flags)
#     274     # internal: compile pattern
#     275     if isinstance(flags, RegexFlag):
# --> 276         flags = flags.value
#     277     try:
#     278         return _cache[type(pattern), pattern, flags]
#
# ~\anaconda3\lib\types.py in __get__(self, instance, ownerclass)
#     169         elif self.fget is None:
#     170             raise AttributeError("unreadable attribute")
# --> 171         return self.fget(instance)
#     172
#     173     def __set__(self, instance, value):
#
# KeyboardInterrupt:

# %% [markdown]
# Wanneer je de code voor de collocatie-analyse hebt uitgevoerd kun je het resultaat opslaan met de code in de onderstaande cel. Deze code maakt een bestand aan met de naam 'collocation.csv' waarin de woorden en de frequenties terug te vinden zijn.
#
# # BESTANDS NAAM VERANDEREN IN DEZE TEKST

# %%
import os
from os.path import join
import re
import pandas as pd
from kitlvTdm import *

# Maximaal aantal woorden waarvan de frequentie wordt opgeslagen in excel bestand, gesorteerd van hoog naar laag.
max = 30

# De naam van het bestand dat wordt opgeslagen.
outFile = 'joden-collocation'

# Maak een Pandas DataFrame, een soort tabel met extra functionaliteit, met gespecificeerde kolom namen.
df = pd.DataFrame(columns = ["term", "frequency"])

# Een teller die op nul staat.
count = 0

# Voor ieder woord in de van hoog naar laag gesorteerde frequenties.
for f in corpusFreqSorted:
    
    # Voeg een rij toe aan het dataframe met de volgende structuur: {"naam van de kolom"} : waarde.
    df = df.append({"term" : f, "frequency" : corpusFreq[f]}, ignore_index = True)
    
    # Tel een op bij de teller
    count += 1
    
    # als het maximaal aantal woorden zijn toegevoegd aan het dataframe stop met toevoegen.
    if count == max:
        break
        
# Sla het DataFrame op als excel bestand.
df.to_excel(outFile + ".xlsx")
print("Excel file saved as " + outFile + "_" + searchTerm + ".xlsx" )
# Out:
# Excel file saved as nazi-collocation_nazi.xlsx

# %% [markdown]
# **Oefening 2: Voer een collocatie-analyse uit, aan de hand van een zoekterm die van belang kan zijn voor jouw onderzoek. Experimenteer met verschillende waarden voor de variabelen `search_term`, `window`.**
