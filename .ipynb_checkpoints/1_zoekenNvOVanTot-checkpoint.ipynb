# %% [markdown]
# ## 1. Zoeken naar een specifieke term, concordantie en export
#
#
#
# Eerst gaan we op zoek naar passages in de 577 digitale teksten waarin een bepaalde term voorkomt. In onderstaande code is het trefwoord een waarde van de variabele `search_term`(bv. “Baboe” of “geweer”). De aanhalingstekens geven aan dat deze waarde variabel is, je kunt deze zoekactie dus herhalen met steeds een ander trefwoord.
#
# Het resultaat van de zoekactie is een lijst met de metadata van alle documenten waarin de opgegeven term voorkomt, met daaronder  alle gevonden passages. Dit is een zogenaamde ‘concordantie’. In het Engels wordt dit een KWIC lijst genoemd, *keyword in context*. Met 'context' wordt bedoeld dat de passages bestaan uit een bepaald aantal woorden voor en na de term. Dit aantal kun je aangeven met de variabele `window`. Als je bv. de waarde 3 invoert, en je zoekt op “geweer”, dan kun je een zin terugkrijgen als ‘ik pak mijn geweer en schiet op’. In het onderstaande voorbeeld gebruiken we de term ‘baboe’ oftewel ‘wasvrouw’, die in veel van de memoires voorkomt.
#
# De metadata die van elk boek beschikbaar zijn, zijn de bibliografische gegevens. Daarnaast is aan elk boek voor het proces van digitaliseren een unieke numerieke code toegekend. Deze vind je terug in de bestandsnamen.
#
# De functie 'showTitle()', in de module kitlvTdm, zoekt de volledige titels die bij deze documentcodes horen. Deze kunnen gevonden worden in het bestand 'metadata.csv'. Dat is een lijst met documentcodes, titels en andere metadata, die ook in de map met alle benodigde data staat, die je van te voren hebt moeten importeren. csv staat voor 'comma separated value', een bestandstype waarbij de waarden niet in aparte velden staan, maar door een comma worden gescheiden.  Dit is een makkelijk te 'lezen' format.
#
# Om stap voor stap te kunnen begrijpen wat je de software vraagt te doen, vind je in elk veld lopende tekst met een uitleg van de afkortingen en de commandos. De uitleg kun je onderscheiden van de echte code doordat die wordt voorafgegaan door een hekje #

# %%
import os
import re
from os.path import join
from kitlvTdm import *
import pandas as pd


path = 'Corpus' 
search_term = 'baboe'
window = 10
max_books = 577
count = 0

for file in os.listdir( path ):
    if re.search( '[.]txt$' , file ) and count < max_books:
        count += 1
        book = open( join( path , file ), encoding = 'utf-8' )
        if re.search( search_term , book.read() , re.IGNORECASE):
            title = showTitle(file)
            print("TITLE:",title)
            book, meta = showYear(file)
            print(f"YEAR: {showYear(file)}")
            concordances = concordance( join( path , file ) , search_term , window )
            
            if len(concordances) > 0:
                print( '\n\nConcordanties in:', title, file, '\n')
                
                for concordantie in concordances:
                    print(concordantie)
# Out:
# BOOKTEST: 03392
# TITLE: De vergeten dagboeken
# BOOKTESTYEAR: 03392
# BOOKTESTYEAR: 03392
# YEAR: ('03392', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
# Concordanties in: De vergeten dagboeken 03392.txt
#
# van aarden en krijg een hele preek mee isan onze baboe staat ons na te wuiven tot we geheel uit het
# mooie benen van elly en etty en lachen naar de baboes die ons lekkere dingen uit de keuken brengen en zelfs
# wakker maar liggen nog in bed zo ook mina de baboe 21e lacht verleidelijk tegen mij de deken gooit ze weg
# natuurlijk weer heerlijk was bespreken we de mogelijkheden om een baboe te krijgen dick heeft natuurlijk weer geweldige plannen en beloften
# kletsen hij zal zorgen dat er binnen het uur een baboe komt ik sta er sceptisch tegenover
# zijn maakt de tafel schoon in één woord een model baboe donderdag 6 februari 1947 tjikalon koelong ik ben vrij en
# de jongens zijn aan het stoeien met de baboe van hier naast eerst laat ik ze hun gang gaan
# het genoeg geweest is onder veel protest stuur ik de baboe naar haar eigen huis maar het blijft nog lang rumoerig
# zwaaiend naar oda mimi tina en hoe al die andere baboe s nog mogen heten vaarwel tjiranjang alweer een episode van
# met de derde compagnie zouden meegaan ik had aan die baboe nog wel gevraagd waar ze woonde maar ik heb alleen
# page 279 jan en kroontje zijn met itje de baboe van de verbindingspost een eindje de kampong in geweest ze
# het was echter te ver zodat ze teruggegaan zijn de baboe lacht hun uit
# al onder de klamboe lig zie ik dat kees onze baboe onna mee neemt onder de klamboe hij doet of het
# je welste dan komt er een heel gedonder over de baboes eerst willen ze alle twee bij ons in de weap
# ons in de weap dan komt van rundberg met de baboe van de v.p die moet ook in de weap daarna
# in de weap daarna komt de telefoonsectie vragen of hun baboe ook in de weap mag enfin het is een gekkenhuis
# het is een gekkenhuis en op het eind moeten alle baboes in een drietonner maar dan komt kees de chauffeur van
# ze ligt op bed en is een beetje overspannen en baboe is er vandaag niet goed dan kom ik morgen wel
# al gauw een 15 wght met een heel stel baboes een leuk ritje naar tjimelakka jammer dat het maar vijf
# ga ik verder de kampong in en vraag naar een baboe die voor ons wil werken maar de mensen zijn nog
# terug en ik spreek af met het grietje dat de baboe om twee uur bij haar huis zal zijn het grietje
# troep van die schoffies voor de deur ze hebben een baboe ik loop mee drie huizen verder staat het wonder ze
# is het niet een schoonheid evenmin maar we hebben een baboe vrijdag 27 februari 1948 telaga
# ik weer bij aangewezen het huis geen man en geen baboe te zien woensdag 3 maart 1948 telaga
# het werk en de boel knapt reusachtig op met deze baboe zal het wel gaan ze blijkt vroeger als baboe in
# deze baboe zal het wel gaan ze blijkt vroeger als baboe in bandoeng gewerkt te hebben en spreekt zelfs een beetje
# we worden begroet door genie koos en de baboes onna en roekia die echt blij zijn dat de toeans
# kees dat hij hem vannacht in het hok achter de baboes gegooid heeft omdat hij zo schreeuwde ik vind het katje
# we worden ontvangen als ere-gasten krijgen thee en koek de baboes van de verbinding hebben ook een ere plaatsje en worden
# BOOKTEST: 03394
# TITLE: Herinneringen van een Roodborstje : verhalen uit de periode 1947-1950 doorgebracht bij het 4e bataljon 5e Regiment Infanterie op Oost-Java in het voormalige Nederlands Oost-Indie?
# BOOKTESTYEAR: 03394
# BOOKTESTYEAR: 03394
# YEAR: ('03394', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
#
#
# Concordanties in: Herinneringen van een Roodborstje : verhalen uit de periode 1947-1950 doorgebracht bij het 4e bataljon 5e Regiment Infanterie op Oost-Java in het voormalige Nederlands Oost-Indie? 03394.txt
#
# bruiloftsstoet 21 10 geestelijk leven 23 11 buitenstaander 25 12 baboe 27 12 aapje 30 13 delicatesse 34 14 heterdaad 36
# de eerste verbazing iaar was bekomen besefte ik dat mijn baboe mij voor een soort stiekeme pedofiel hield vrij zeker tot
# bij elkaar zat de onderofficier vertelde mij dat dit de baboes waren die waren de aangesteld voor het wassen van de
# de post had bezet per tien soldaten was organiek één baboe beschikbaar zon n p baboe was in de voeding bij
# tien soldaten was organiek één baboe beschikbaar zon n p baboe was in de voeding bij de troep en werd voor
# die zegt dat ze graag baboe bij de soldaten wil worden hoe moet ik daarmee 8e
# 8e aan als omdat tom dwars alle zaken regelde betreffende baboes en djongossen nam hij ien het gesprek over laat ze
# niet goedkope sarong en dito kanten kabaja terwijl al onze baboes op len blote voeten liepen droeg zij met gratie een
# haar dat ons onderdeel voorzien was van het organieke aantal baboes en dat hij haar dus niet mocht aannemen ze was
# surabaya stond in de bijgebouwtjes achter deze panden vonden de baboes onderdak eén en ander voor zover deze dames niet in
# BOOKTEST: 03395
# TITLE: Het reizende bataljon : herdenkingsboek 8 RS
# BOOKTESTYEAR: 03395
# BOOKTESTYEAR: 03395
# YEAR: ('03395', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
#
#
# Concordanties in: Het reizende bataljon : herdenkingsboek 8 RS 03395.txt
#
# dronken gevoerd en werd getracht mij een van hun vele baboes aan te smeren die gelukkig zei tida mau toean dat
# BOOKTEST: 03396
# TITLE: Als de natuur zwijgt (1945)
# BOOKTESTYEAR: 03396
# BOOKTESTYEAR: 03396
# YEAR: ('03396', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
#
#
# Concordanties in: Als de natuur zwijgt (1945) 03396.txt
#
# wassen is niet meer nodig de meeste secties hebben een baboe die voor hen dagelijks de kleren wast en strijkt strijken
# wassen is niet meer nodig de meeste secties hebben een baboe die voor hen dagelijks de kleren wast en strijkt strijken
# naar ons roepen tabeh toean zit me daar warempel onze sectiebaboe op het balkon dagelijks komt ze onze kleren wassen en
# is een rustige omgeving en hopelijk vinden we hier een baboe voor onze was ondanks al dat primitieve gedoe krijgen ze
# BOOKTEST: 03398
# TITLE: Op de plaats rust
# BOOKTESTYEAR: 03398
# BOOKTESTYEAR: 03398
# YEAR: ('03398', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
# Concordanties in: Op de plaats rust 03398.txt
#
# m m mm wij konden het goed vinden met onze baboes voor een geliefd decor de sierlijke palmboom poseerden zij met
# wat zouden dan die meisjes kijken nu kijkt zelfs de baboe niet stel je voor dat ons majoortje s morgens vroeg
# BOOKTEST: 03399
# TITLE: Herinneringen : memoires van een christen, militair en politicus
# BOOKTESTYEAR: 03399
# BOOKTESTYEAR: 03399
# YEAR: ('03399', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
# BOOKTEST: 03400
# TITLE: Voor ik het nooit vergeet : herinneringen van een 4-2 R.I'er op Noord-Sumatra : gebaseerd op dagboekaantekeningen over de periode van 7 november 1946 tot en met 24 februari 1950
# BOOKTESTYEAR: 03400
# BOOKTESTYEAR: 03400
# YEAR: ('03400', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
#
#
# Concordanties in: Voor ik het nooit vergeet : herinneringen van een 4-2 R.I'er op Noord-Sumatra : gebaseerd op dagboekaantekeningen over de periode van 7 november 1946 tot en met 24 februari 1950 03400.txt
#
# het ogenblik ringworm en rode hond het jeukt ontzettend de baboe is net op bezoek geweest en het kleine chinese meisje
# met het uitdelen van rijst en katoen aan de honderdvijftig baboes en koelies van ons bataljon krentenbrood vandaag wel lekker maar
# page 77 talen aan de baboes en koelies druk dus er is een grote actie ingezet
# er elke dag wel acht soldaten hebben recht op één baboe voor de een complete verschoning van ondergoed tot was en
# frans probleempje even is het stil ik hoor buiten de baboe schuifelen over de pendopo ze komt de vuile was ophalen
# naar bindjei rijst halen om uit te delen aan de baboes stukje voor de gong geschreven 14 augustus 1948 weer wat
# in één keer geslacht gebraden en opgediend door onze onvolprezen baboe marianne omdat de schaal zo hoog was opgeladen met kippenboutjes
# de baboe en de djongos waren ervan overtuigd dat het een civetkat
# BOOKTEST: 03402
# TITLE: Orde en vrede' : de humanitaire/militaire missie in Nederlands Oost-IndiÃ« 1945-1950 (1997)
# BOOKTESTYEAR: 03402
# BOOKTESTYEAR: 03402
# YEAR: ('03402', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
# Concordanties in: Orde en vrede' : de humanitaire/militaire missie in Nederlands Oost-IndiÃ« 1945-1950 (1997) 03402.txt
#
# mocht hijzelf wassen tenzij het mogelijk was geweest om een baboe te organiseren de onderkomens waren meestal niet zo riant en
# BOOKTEST: 03404
# TITLE: IndonesiÃ« op het tweede gezicht : een laat weerzien met terugblikken naar toen
# BOOKTESTYEAR: 03404
# BOOKTESTYEAR: 03404
# YEAR: ('03404', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
#
#
# Concordanties in: IndonesiÃ« op het tweede gezicht : een laat weerzien met terugblikken naar toen 03404.txt
#
# ook nadrukkelijk de vraag op wat gebeurt er met de baboe en de djongos ais wij verdwenen zijn hoe zal hun
# wind atap soort dakbedekking atas semua voor alles babi varken baboe babu hulp in de huishouding baik goed gunstig bajar membajar
# BOOKTEST: 03405
# TITLE: 50 jaar na dato,' 1946-1996
# BOOKTESTYEAR: 03405
# BOOKTESTYEAR: 03405
# ...
#
#
# Concordanties in: Thuisreis van het 3e bataljon Stoottroepen met het M.S. Kota-Inten, Tandjong-Priok/Rotterdam 03409.txt
#
# van inladen is daar een laatste groet aan de vertrouwde baboes en djonggossen en aan de kampongbevolking die aan weerszijden van
# 4e compie page 46 page 47 woordvertalina patria kampong toekankajoe baboe djongos havengoedang koelie mandoer teng-teng kretek tampat passar kalie k.n.i.l
# BOOKTEST: 03410
# TITLE: Militaire politie in Nederlands-IndiÃ« 1945-1951
# BOOKTESTYEAR: 03410
# BOOKTESTYEAR: 03410
# YEAR: ('03410', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
# Concordanties in: Militaire politie in Nederlands-IndiÃ« 1945-1951 03410.txt
#
# burgerpersoneel dat ten behoeve van het detachement diensten verrichtte als baboe-tjoetji wasvrouw en koki kokki
# uitrusting meestal uitgevoerd in onderkleding deze werd dagelijks door de wasbaboes één baboe verzorgde zes man gereinigd teneinde verwisseling van de
# uitgevoerd in onderkleding deze werd dagelijks door de wasbaboes één baboe verzorgde zes man gereinigd teneinde verwisseling van de te wassen
# gemerkt met zo mogelijk onuitwisbare inkt dit leverde voor de baboes veelal analfabeet geen problemen op
# het burgerpersoneel zoals de baboes djongossen koks technischen administratief personeel stond bloot aan bedreigingen met
# BOOKTEST: 03411
# TITLE: De Indie?gangers : over de in de jaren 1945-1950 uit Hardinxveld en Giessendam uitgezonden militairen in de oorlog met de Republiek Indonesie?
# BOOKTESTYEAR: 03411
# BOOKTESTYEAR: 03411
# YEAR: ('03411', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
#
#
# Concordanties in: De Indie?gangers : over de in de jaren 1945-1950 uit Hardinxveld en Giessendam uitgezonden militairen in de oorlog met de Republiek Indonesie? 03411.txt
#
# van geestelijke en sexuele aard de inlandse vrouwen vooral de wasbaboes in de kazernes zijn een gevaar de ontspanning die de
# zoals mannen die de vrachtwagens laadden en losten en de baboes met zes man hadden we een baboe voor het opruimen
# losten en de baboes met zes man hadden we een baboe voor het opruimen van de kamers wassen strijken en dergelijke
# inlandse bevolking had je behalve met het eigen personeel zoals baboes en djongossen weinig contact maar als ik onderweg in een
# aanen afvoer troepen arp anti-revolutionaire partij bahasa indonesia indonesische taal baboe vrouwelijke indonesische huisbediende of wasvrouw belanda nederlander
# BOOKTEST: 03412
# TITLE: Vertel het je kinderen, veteraan!
# BOOKTESTYEAR: 03412
# BOOKTESTYEAR: 03412
# YEAR: ('03412', {'03818': ('1991', <built-in method strip of str object at 0x000002A56C303E90>, 'Mijn militaire memoires: de mooie\\, minder mooie\\, trieste en uiteindelijk bittere ervaringen van een reserve-officier\\, opgedaan vÃ³Ã³r\\, tijdens en na de 2e Wereldoorlog'), '03829': ('1992', <built-in method strip of str object at 0x000002A56C4B1C30>, 'Herinneringen van toenâ€¦ Enkele fragmenten uit het leven van Jacob Moen'), '03831': ('2005', <built-in method strip of str object at 0x000002A56C4EC5D0>, 'Mijn levensloop\\, 1920-1950'), '03828': ('2004', <built-in method strip of str object at 0x000002A56C432A80>, 'On active service. 27 juni 1946 - 18 september 1946. Briefverslag van zijn uitzending als army doctor naar Nederlands IndiÃ«.'), '03833': ('', <built-in method strip of str object at 0x000002A56C4B1DF0>, '"Repliek. Nederlands-Oost-IndiÃ«'), '03826': ('2001', <built-in method strip of str object at 0x000002A56C4ECBC0>, 'Tussen kolonie en merdeka.'), '03824': ('1939', <built-in method strip of str object at 0x000002A56C4B1AF0>, 'Herinneringen van Co Broerse uit de jaren 1939-1950. Grotendeels geput uit de vele brieven aan zijn moeder in de periode 1945-1950.'), '03822': ('1949', <built-in method strip of str object at 0x000002A56C4B17B0>, 'De geschiedenis van 3. Garderegiment Prinses Irene'), '03845': ('1984', <built-in method strip of str object at 0x000002A56C439CB0>, 'Het vergeten leger : het 425e bataljon infanterie'), '03844': ('2014', <built-in method strip of str object at 0x000002A56C439030>, 'Diensplichtigen in Indie 1957/1949'), '03825': ('1946', <built-in method strip of str object at 0x000002A56C4B1570>, 'Het verhaal van een dienstplichtig soldaat.'), '03843': ('1950', <built-in method strip of str object at 0x000002A56C4B1D30>, '5-1 R.I. in de tropen'), '03823': ('1949', <built-in method strip of str object at 0x000002A56C40F170>, 'Djokja achter de horizon'), '03836': ('2009', <built-in method strip of str object at 0x000002A56C43BE90>, 'Ontmoeten en herdenken: Terugblik op de reÃ¼nies van 5-5 R.I.'), '03842': ('1994', <built-in method strip of str object at 0x000002A56C4B1BF0>, 'Verbindingsmannen Onder De Palmen'), '03832': ('2012', <built-in method strip of str object at 0x000002A56C336450>, '"De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene"""'), '03820': ('1984', <built-in method strip of str object at 0x000002A56BAA3AB0>, '"""Zelfportret"" van de 31e Hp.V.A.: 17 september 1946 tot 20 februari 1950. Uitgegeven ter gelegenheid van de vierde reÃ¼nie van het onderdeel in Alphen aan de Rijn op 8 september 1984"'), '03830': ('2011', <built-in method strip of str object at 0x000002A56BAA38F0>, 'Indisch avontuur van een dienstplichtig soldaat'), '03839': ('1995', <built-in method strip of str object at 0x000002A56C35B4E0>, 'Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars'), '03834': ('2006', <built-in method strip of str object at 0x000002A56C4ABB70>, 'Een verleden herleefd: IndiÃ« 1948-1950'), '03994': ('1992', <built-in method strip of str object at 0x000002A561F351B0>, 'De witte karbouw : herinneringen aan een oorlog in de tropen'), '03998': ('1993', <built-in method strip of str object at 0x000002A561F351B0>, 'De verliezers : IndonesiÃ« op het tweede gezicht'), '03935': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Kennemers\\, watermannen en rijstvogels'), '03997': ('1640', <built-in method strip of str object at 0x000002A561F351B0>, 'Catalogus bibliothecÃ¦ publicÃ¦ lvgdvno-batavÃ¦ noviter recognitus'), '03934': ('', <built-in method strip of str object at 0x000002A561F351B0>, "Soldaat in Nederlands Indie? : dienstplichtige jongens en OVW'ers uit Achterveld\\, Stoutenburg en directe omgeving in Nederlands Oost Indie?"), '03816': ('', <built-in method strip of str object at 0x000002A561F351B0>, 'Gadja merah op Bali en Lombok.'), '03817': ('1946', <built-in method strip of str object at 0x000002A561F351B0>, 'Demarcatielijn'), ' ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_5596/1417370022.py in <module>
#      26             book, meta = showYear(file)
#      27             print(f"YEAR: {showYear(file)}")
# ---> 28             concordances = concordance( join( path , file ) , search_term , window )
#      29
#      30             if len(concordances) > 0:
#
# ~\Documents\Niels\projectjes\Stef\kitlvTdm.py in concordance(book, searchTerm, distance)
#     149         else:
#     150             parLength = 0
# --> 151             words = tokenise( paragraph )
#     152             i = 0
#     153             for w in words:
#
# ~\Documents\Niels\projectjes\Stef\kitlvTdm.py in tokenise(text)
#     283     text = text.lower()
#     284     text = re.sub( '--' , ' -- ' , text)
# --> 285     words = re.split( r'\s+' , text )
#     286     i = 0
#     287     for w in words:
#
# KeyboardInterrupt:

# %% [markdown]
# `path`
#
# Dit staat voor het pad naar de folder waar je de grote hoeveelheid tekst data kunt vinden, in ons geval gaat het om de folder 'corpus' (linguisten noemen een verzameling teksten een corpus). Het gaat erom aan te geven waar dit bestand staat op je computer.
#
# …/ #betekent een map “omhoog” of “terug”. Hier ga je dus een map omhoog, en naar de map corpus.
#
# `search_term`
#
# Dit staat voor de zoekterm
#
# `window`
#
# Dit staat voor het aantal woorden dat voor en na de zoekterm meegenomen wordt in de resultaten
#
# `max_books`
#
# Dit geeft aan dat we een limiet stellen aan het aantal boeken dat doorzocht moet worden. (dit is handig om te doen als je te maken hebt met een massale hoeveelheden data, dan probeer je eerst of een zoekterm iets oplevert in 100 boeken, want dat gaat veel sneller, en dan probeer je het uit in de totale hoeveelheid boeken, een paar 1000.
#
#
# `count`
#
# Dit is de opdracht om bij te houden hoeveel boeken er al doorzocht zijn. Dit maakt het mogelijk om een indruk te krijgen van de tijd die het proces inneemt.
#
# `for file in os.listdir( path ):`
#
# Dit is de opdracht over wat er moet gebeuren met ieder bestand dat zich bevindt in de directory van het operating system en bereikt kan worden via dit #pad (gaat verder op volgende regel)
#
# `if re.search( '[.]txt$' , file ) and count < max_books:`
#
#
# als het om een tekstbestand gaat (regular expression), sla deze dan op en ga door met de volgende. Ook wordt hier aangegeven of het aantal doorzochte boeken minder is dan het maximum aantal boeken. Er moet dus aan twee voorwaarden voldaan worden om het proces van doorzoeken voort te zetten:
#
# 1. het moet om een tekstbestand gaan (True) en
# 2. je moet nog niet het einde van de lijst hebben bereikt(True)
#
#
# `count +=1`
#
# Dit geeft de opdracht om als het om een boek gaat, 1 boek op te tellen bij het aantal doorzochte boeken
#
#
# `book = open( join( path , file), encoding = ‘utf-8’)`
#
# Dit staat voor: Open het boek en voeg de locatie van het corpus (path) en de bestandsnaam van het boek (file) samen. Gebruik hiervoor ‘utf-8’, dat staat voor een codering die bepaalt hoe de bits worden omgezet in letters.
#
#
# `if re.search( search_term , book.read() , re.IGNORECASE):`
#
# Dit staat voor: als de zoekterm in een boek gevonden is,  waarbij je niet op hoofdletters of kleine letters let (gaat verder op volgende regel)
#
#
# `title = showTitle(file)` -
#
# sla dan de titel op in de variabele 'title'
#
#
# `concordances = concordance ( join( path, file ) , search_term , window) `
#
# Dit staat voor: zoek voor concordantie(s) in het boek op basis van de zoekterm en neem het aantal woorden ervoor en erna mee, sla ze op in de variabele concordances die alle gevonden concordanties bij elkaar brengt
#
#
# `if len(concordances) > 0:`
#
# Dit staat voor: als er al één match is gevonden, dan is het aantal matches (length) dus groter dan 0. Dit is een soort controle, om te checken of er überhaupt iets is gevonden)
#
#
# `print(‘\n\nConcordanties in:’,title, file,’\n’)`
#
# Dit staat voor: als er matches gevonden zijn laat dan de titel en naam van het bestand (boek) zien
#
# `for concordantie in concordances:`  - per gevonden concordantie
#
# `print (concordantie)` - laat de gevonden concordantie zien

# %% [markdown]
# In de bovenstaande code worden de resultaten simpelweg getoond in dit Notebook. Je kunt uiteraard ook de resultaten exporteren naar een ander bestandstype, zodat je er ook in andere programma's mee kunt werken (Google sheets of Excel). Dan kun je kolommen toevoegen met je eigen commentaar of codes in de spreadsheet.
#
# Om dit te kunnen doe hebben we zogenaamde 'pandas' nodig, dat staat voor Python Data Analysis Library, of eenvoudiger Panel Data, een dataframe in Python taal, die je kunt exporteren.
#
# een pandas bestand wordt dus herkend door Google sheets en Excel.
#
# De naam van dit tekstbestand wordt bepaald door de variabele 'outFile'.
#
# In dit export bestand wordt ook het aantal treffers geteld, het totaal aantal treffers in het hele corpus, maar ook het aantal treffers per egodocument.
#
# Ook hier volgt eerst de code, met daaronder per regel een uitleg. Omdat een heleboel regels hetzelfde zijn als in het vorige deel, worden alleen de nieuwe regels uitgelegd.
#
# Behalve code voor het exporteren van de resultaten in een dataframe, heb je ook code nodig om aan te geven waar de data naar toe moet. De code hieronder zorgt ervoor dat je tabel met zoekresultaten in dezelfde map terecht komt als waar de andere onderdelen die je gebruikt hebt staan.

# %%
#### path = 'Corpus'
import os
import re
from os.path import join
from kitlvTdm import *
import pandas as pd

searchTerm = 'baboe'
window = 10
outFile = 'concordantie'
df = pd.DataFrame(columns = ['count_within_document','file','title','fragment'])
for file in os.listdir( path ):
    if re.search( '[.]txt$' , file ):
        documentCount = 0 
        book = open( join( path , file ), encoding = 'utf-8' )
        
        if re.search( searchTerm , book.read() , re.IGNORECASE ):
            title = showTitle(file)
            concordances = concordance( join( path , file ) , searchTerm , window )
            
            for conc in concordances:
                documentCount += 1
                df = df.append({'count_within_document' : documentCount, 'file' : file,
                                'title' : title, 'match' : conc}, ignore_index = True)
                
df.to_excel(outFile + "concordantie" + "baboe" + ".xlsx")
print("Excel file saved as concordantie" + outFile + "concordantie" + "baboe" + ".xlsx" )
# Out:
# Excel file saved as concordantieconcordantieconcordantierazzia.xlsx

# %% [markdown]
# ####
#
# `searchTerm = bekend
# `window = bekend
#
# `outFile = 'concordantie'`
#
# Dit staat voor: voeg hier de naam toe van het bestand waar de resultaten in zullen worden opgeslagen
#
# `df = pd.DataFrame(columns = ['count_within_document','file','title','fragment'])` -
#
# Dit staat voor: maak een Pandas DataFrame aan (een soort grote tabel waarin we resultaten
# kunnen opslaan als in een Excel bestand)
#
# Maak daarbij steeds een nieuwe rij in de tabel aan met de volgende opmaak. 'kolom' 'titel' 'variabele'
#
# deze code is een herhaling van wat bij de eerste module is gebruikt:
#
# for file in os.listdir( path ):
#     if re.search( '[.]txt$' , file ):
#         documentCount = 0
#         book = open( join( path , file ), encoding = 'utf-8' )
#
#         if re.search( searchTerm , book.read() , re.IGNORECASE ):
#             title = showTitle(file)
#             concordances = concordance( join( path , file ) , searchTerm , window )
#
#             for conc in concordances:
#                 documentCount += 1
#
#
# `df = df.append({'count_within_document' : documentCount, 'file' : file, 'title' : title, 'match' : conc}, ignore_index = True)` -
#
# Dit staat voor: maak een nieuwe rij in de tabel met de volgende opmaak. "kolom titel : variabele".  Ga daarna verder naar de volgende concordantie in dit boek. Als er geen meer zijn: ga verder naar het volgende bestand.
#
#
# `df.to_excel(outFile + "_" + searchTerm + '.xlsx')`
#
# Dit staat voor: Wanneer alle boeken doorzocht zijn, sla de tabel op als een excel bestand in de map results, met de naam gespecificeerd in de variabele "outFile" plus de zoekterm.

# %% [markdown]
# **Oefening 1: Experimenteer eerst met een andere zoektermen en een ander bereik, bijvoorbeeld 20 woorden er voor en er na, door de waarden van de variabalen `search_term` en `window` aan te passen. Klik vervolgens op [Shift] + [Enter].**
