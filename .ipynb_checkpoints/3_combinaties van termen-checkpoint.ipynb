# %% [markdown]
# # 3. Zoeken naar een combinatie van termen
# Als je op zoek bent naar samenhang tussen twee zaken wil je testen of de termen die naar die zaken verwijzen inderdaad in combinatie met elkaar voorkomen. Dan moet je bepalen op welke varianten van die twee termen je wilt zoeken en wat de minimale en maximale afstand tussen die termen moet zijn.
#
# In de onderstaande code kun je op de eerste plaats twee zoektermen opgeven, als waarden van `search_term1` en `search_term2`. De variabele `window` specificeert de maximale afstand tussen deze twee woorden.
#
# De code gaat vervolgens op zoek naar alle passages van de opgegeven lengte waar de beide zoektermen in voorkomen. De gevonden passages worden in dit notebook getoond wanneer de code wordt uitgevoerd, en de resultaten worden eveneens weggeschreven in een bestand met de naam 'cooccurrence.txt'.

# %%
from kitlvTdm import *
import os
from os.path import join
import re
import pandas as pd

# %%
# Defineer de zoektermen en de seach window
search_term1 = 'soldaat'
search_term2 = 'geweer'
window = 30

# In deze map gaat er gezocht worden
path = "Corpus"

df = pd.DataFrame(columns = ['count_within_document','file','title','fragment'])

# Het zoeken is hoofdletter gevoelig, daarom worden alle hoofdletters in kleine letters veranderd, hier en in de corpus.
search_term1 = search_term1.lower()
search_term2 = search_term2.lower()

pattern = '####'


# Voor ieder bestand in de eerder gedefineerde map
for file in os.listdir( path ):
    
    # Laat zien welk bestand het programma aan het lezen is
    print( "Reading " + file + ' ... ' )
    
    # Maak een lijst aan waar alle fragmenten in komen
    fragments = []
    
    # Als het bestand een tekst bestand is:
    if re.search( 'txt$' , file ):
        
        # Open het bestand en laad de tekst in de variabele 'fullText'
        with open( join( path , file) , encoding = 'utf-8') as egodocument:
            fullText = egodocument.read()
            
        # Zoek en sla alleen de tekst op van iedere bladzijde (bijvoorbeeld niet het bladzijde nummer)
        fullText = re.sub( 'page\s+\d+', '' , fullText )
        
        # Verander alle hoofdletters in kleine letters
        fullText =  fullText.lower()
        
        # Identificeer de losse woorden
        words = tokenise(fullText)
        
        # Voor iedere locatie van een woord
        for i in range( 0 , (len(words)) ):
            
            # creeer een fragment van de grootte die gespecificeerd is in 'window'
            fragment = ' '.join( words[ i : window+i ] )
            
            # als de gezochte woorden beide voorkomen als los woord in het fragment
            if re.search( r'\b{}\b'.format(search_term1) , fragment , re.IGNORECASE ) and re.search( r'\b{}\b'.format(search_term2) , fragment , re.IGNORECASE ):
                
                '''
                Dit stukje zorgt ervoor dat een fragment niet vaker gevonden wordt. Als er één woord tussen soldaat en geweer zit
                en de 'window' is 30 zijn er 27 verschillende fragmenten voor dezelfde gevonden combinatie.
                Om dit te voorkomen wordt er gekeken of in een gevonden fragment de zoektermen op een andere manier tot elkaar staan
                en daarmee ook daadwerkelijk een nieuw fragment zijn.                
                '''
                if not( re.search( pattern , fragment , re.IGNORECASE ) ):
                    
                    # Voeg het gevonden fragment toe aan de lijst fragments
                    fragments.append( fragment )
            
                    # Voor ieder nummer tussen 0 en het nummer 'window'
                    for findex in range( 0 , window ):
                        
                        # Als de het patroon al bekent is stop met de bovenstaande 'for loop'
                        if re.search( r'\b{}\b'.format(search_term1) , words[i + findex] , re.IGNORECASE ) or re.search( r'\b{}\b'.format(search_term2) , words[i + findex] , re.IGNORECASE ):
                            break
                    
                    # Anders update de variabele pattern naar het nieuw gevonden patroon
                    pattern = ' '.join( words[ i + findex : window+i  ] )

            # Tel een op bij de plek waar we zijn bij het doorzoeken van de woorden (bovenste for loop)
            i = window + i
            
    documentCount = 0
    # Als er resultaten gevonden zijn
    if len(fragments) > 0:
        
        # Vind de titel van het boek en sla het op in de variabele 'title'
        title = showTitle(file)
        
        # Laat het volgende zien met de titel en de naam van het bestand
        print("Occurrences in {} ({})\n".format( title , file ))
        
        # Voor ieder gevonden fragment 
        for fragment in fragments:
            
            documentCount += 1
            
            # Laat het fragment zien
#             print(h + '\n')
            
            # Schrijf het fragment op in het bestand
            df = df.append({'count_within_document' : documentCount,'file' : file, 'title' : title, 'fragment' : fragment}, ignore_index = True)

df.to_excel(f"combination_{searchterm1}_{searchterm2}.xlsx")
print(f"Excel file saved as combination_{searchterm1}_{searchterm2}.xlsx")
# Out:
# Reading 03391.txt ...
# Reading 03392.txt ...
# Occurrences in De vergeten dagboeken (03392.txt)
#
# Reading 03393.txt ...
# Occurrences in Hij ging, kwam terug en keerde weer (03393.txt)
#
# Reading 03394.txt ...
# Reading 03395.txt ...
# Reading 03396.txt ...
# Occurrences in Als de natuur zwijgt (1945) (03396.txt)
#
# Reading 03398.txt ...
# Reading 03399.txt ...
# Occurrences in Herinneringen : memoires van een christen, militair en politicus (03399.txt)
#
# Reading 03400.txt ...
# Reading 03401.txt ...
# Reading 03402.txt ...
# Reading 03403.txt ...
# Reading 03404.txt ...
# Occurrences in IndonesiÃ« op het tweede gezicht : een laat weerzien met terugblikken naar toen (03404.txt)
#
# Reading 03405.txt ...
# Reading 03406.txt ...
# Reading 03407.txt ...
# Reading 03408.txt ...
# Reading 03409.txt ...
# Reading 03410.txt ...
# Reading 03411.txt ...
# Reading 03412.txt ...
# Reading 03413.txt ...
# Reading 03414.txt ...
# Reading 03415.txt ...
# Reading 03416.txt ...
# Occurrences in De grote patrouille : belevenissen van het bataljon 5-4 R.I. in Zuid- en Oost-Borneo, Zuid-Sumatra en Oost-Java in de jaren 1947, 1948, 1949, 1950 (03416.txt)
#
# Reading 03417.txt ...
# Reading 03418.txt ...
# Occurrences in Levenslang op patrouille (1946) (03418.txt)
#
# Reading 03419.txt ...
# Reading 03420.txt ...
# Reading 03421.txt ...
# Reading 03422.txt ...
# Reading 03423.txt ...
# Occurrences in De hemelse kwartiermaker : brieven van een jonge Maastrichtse oorlogsvrijwilliger aan zijn thuisfront, 1945-1947 (03423.txt)
#
# Reading 03424.txt ...
# Reading 03425.txt ...
# Occurrences in Verhalen van toen : Regiment Stoottroepen 50 jaar (03425.txt)
#
# Reading 03426.txt ...
# Reading 03427.txt ...
# Occurrences in Na vijftig jaar : dagboekherinneringen van een soldaat in Indie?, 1949-1950 (03427.txt)
#
# Reading 03428.txt ...
# Reading 03429.txt ...
# Occurrences in "Soldaat E. Kerkdijk : registratienummer 25.12.12.159 (03429.txt)
#
# Reading 03430.txt ...
# Reading 03431.txt ...
# Reading 03432.txt ...
# Occurrences in De laatste patrouille (1949) (03432.txt)
#
# Reading 03433.txt ...
# Reading 03434.txt ...
# Reading 03435.txt ...
# Reading 03436.txt ...
# Reading 03437.txt ...
# Occurrences in De laatste patrouille' : episode 1946-1950, Midden-Java (03437.txt)
#
# Reading 03438.txt ...
# Occurrences in Dikke zoen voor Moeke : brieven van een soldaat in IndiÃ« 1949-1950 (03438.txt)
#
# Reading 03439.txt ...
# Reading 03440.txt ...
# Reading 03441.txt ...
# Occurrences in Logboek 1-41 RVA : verhalen en wetenswaardigheden (03441.txt)
#
# Reading 03442.txt ...
# Reading 03443.txt ...
# Reading 03444.txt ...
# Reading 03445.txt ...
# Reading 03446.txt ...
# Reading 03447.txt ...
# Occurrences in Uust me? (03447.txt)
#
# Reading 03448.txt ...
# Reading 03449.txt ...
# Occurrences in Op patrouille in blessuretijd (1946) (03449.txt)
#
# Reading 03450.txt ...
# Reading 03451.txt ...
# Occurrences in Het dagboek van een gesneuvelde soldaat (1948) (03451.txt)
#
# Reading 03452.txt ...
# Occurrences in IndiÃ«-veteraan ben je levenslang (03452.txt)
#
# Reading 03453.txt ...
# Reading 03454.txt ...
# Reading 03455.txt ...
# Reading 03456.txt ...
# Occurrences in IndiÃ« blijft ons bezighouden (03456.txt)
#
# Reading 03457.txt ...
# Occurrences in Camouflagepak, politiepet en narrenkap (03457.txt)
#
# Reading 03458.txt ...
# Reading 03459.txt ...
# Reading 03460.txt ...
# Reading 03461.txt ...
# Reading 03462.txt ...
# Reading 03463.txt ...
# Reading 03464.txt ...
# Reading 03465.txt ...
# Reading 03466.txt ...
# Occurrences in Een Indonesie? weigeraar vertelt zijn verhaal : Jan Maassen over strijd en gevangenschap (03466.txt)
#
# Reading 03467.txt ...
# Occurrences in Respect en erkenning : veteranen Schaijk-Reek in Nederlands-Indie? 1945-1950 (03467.txt)
#
# Reading 03468.txt ...
# Reading 03469.txt ...
# Reading 03470.txt ...
# Occurrences in Een Zandbergse jongen : Indisch dagboek 1946 (03470.txt)
#
# Reading 03471.txt ...
# Reading 03472.txt ...
# Reading 03473.txt ...
# Reading 03474.txt ...
# Reading 03475.txt ...
# Reading 03476.txt ...
# Reading 03477.txt ...
# Reading 03478.txt ...
# Occurrences in Onhoorbaar groeit de padi : front-soldaten in een verloren oorlog : Indonesie 1948-1950 (03478.txt)
#
# Reading 03479.txt ...
# Occurrences in Indonesie? als eindstation : met het vergeten leger in Indie? (03479.txt)
#
# Reading 03480.txt ...
# Occurrences in Eens marinier altijd marinier : een leven vol afwisseling en avontuur : Qua Patet Orbis 1940-1972 (03480.txt)
#
# Reading 03482.txt ...
# Occurrences in Bij de inlichtingendienst op Midden-Java (03482.txt)
#
# Reading 03483.txt ...
# Reading 03484.txt ...
# Reading 03485.txt ...
# Reading 03486.txt ...
# Occurrences in Nou, tabee dan, ik groet je... : wetenswaardigheden van een vijfjarig verblijf in IndiÃ« 1945-1949 (03486.txt)
#
# Reading 03487.txt ...
# Reading 03488.txt ...
# Reading 03489.txt ...
# Reading 03490.txt ...
# Reading 03491.txt ...
# Occurrences in Duizend dagen IndiÃ« : het dagboek van Jan van Trigt 1945-1948 (03491.txt)
#
# Reading 03492.txt ...
# Reading 03493.txt ...
# Reading 03494.txt ...
# Occurrences in 3-41 R.V.A. in de tropen (1948) (03494.txt)
#
# Reading 03495.txt ...
# Reading 03496.txt ...
# Occurrences in IndiÃ« blijft onze denkwereld : met het vergeten leger in IndiÃ« (03496.txt)
#
# Reading 03497.txt ...
# Reading 03498.txt ...
# Occurrences in Opdracht uitgevoerd : een verhaal over de Tweede Wereldoorlog die voor de Nederlandse jongens 10 jaar duurde (03498.txt)
#
# Reading 03499.txt ...
# Reading 03500.txt ...
# Reading 03501.txt ...
# Reading 03502.txt ...
# Reading 03503.txt ...
# Reading 03504.txt ...
# Reading 03505.txt ...
# Reading 03506.txt ...
# Reading 03507.txt ...
# Occurrences in Soldaat zonder franje (1928) (03507.txt)
#
# Reading 03508.txt ...
# Reading 03509.txt ...
# Occurrences in Vaarwel, kameraad! : met het vergeten leger in Indie? (03509.txt)
#
# Reading 03510.txt ...
# Reading 03511.txt ...
# Occurrences in Herinneringen aan de 42e Zibva (03511.txt)
#
# Reading 03512.txt ...
# Reading 03513.txt ...
# Reading 03514.txt ...
# Reading 03515.txt ...
# Reading 03516.txt ...
# Occurrences in Het oerwoud beangstigt mij! : dagboek van een dienstplicht (03516.txt)
#
# Reading 03517.txt ...
# Occurrences in De marsroute van 1-11 R.I. (03517.txt)
#
# Reading 03518.txt ...
# Occurrences in Staphorster militairen in de tropen (03518.txt)
#
# Reading 03519.txt ...
# Occurrences in Klappermelk & klompen : veteranen vertellen over Nederlands-IndiÃ« en Nieuw-Guinea (03519.txt)
#
# Reading 03520.txt ...
# Reading 03521.txt ...
# Occurrences in Verhalen van veteranen : gesprekken met veteranen (03521.txt)
#
# Reading 03522.txt ...
# Reading 03523.txt ...
# Reading 03524.txt ...
# Occurrences in Mijn Ruiters : ervaringen als commandant van het 4e Eskadron Pantserwagens, Huzaren van Boreel, tijdens de politionele acties (1947-1949) in toenmalig Nederlands-IndiÃ« (03524.txt)
#
# Reading 03525.txt ...
# Reading 03526.txt ...
# Reading 03527.txt ...
# Reading 03528.txt ...
# Reading 03529.txt ...
# Reading 03530.txt ...
# Reading 03531.txt ...
# Occurrences in Mijn oorlog, mijn hart (03531.txt)
#
# Reading 03532.txt ...
# Occurrences in Daar woonde mijn huis en daar sliep mijn bed : het verhaal over mijn diensttijd in IndiÃ« (1947 t/m 1950) (03532.txt)
#
# Reading 03533.txt ...
# Reading 03534.txt ...
# Reading 03535.txt ...
# Occurrences in Omstreden paradijs : ooggetuigen van Nederlands-IndiÃ« (03535.txt)
#
# Reading 03536.txt ...
# Reading 03537.txt ...
# Reading 03538.txt ...
# Reading 03539.txt ...
# Reading 03540.txt ...
# Reading 03541.txt ...
# Reading 03542.txt ...
# Reading 03543.txt ...
# Reading 03544.txt ...
# Reading 03545.txt ...
# Occurrences in Onze joo?s in de tropen 1945-1950 (03545.txt)
#
# Reading 03546.txt ...
# Occurrences in Kemphanen : herinneringen aan 2-3-12 R.I. (03546.txt)
#
# Reading 03547.txt ...
# Reading 03548.txt ...
# Reading 03549.txt ...
# Reading 03550.txt ...
# Reading 03551.txt ...
# Occurrences in De sobats van Co Groen' : 43 Genieveldcompagnie in Nederlands-IndiÃ« 1949-1950 (03551.txt)
#
# Reading 03552.txt ...
# Reading 03553.txt ...
# Reading 03554.txt ...
# Reading 03555.txt ...
# Reading 03556.txt ...
# Reading 03557.txt ...
# Occurrences in Toen had je de politionele acties : maar zonder 5-2 RI : 5-2 RI, 1947-1950: Nijmegen, Celebes, Java, Sumatra, Borneo : een beknopte geschiedenis van het bataljon 5-2 RI tegen de achtergrond van het Nederlands-Indonesisch conflict aan de hand van de belevenissen van soldaat eerste klas Nico Messing (2008) (03557.txt)
#
# Reading 03558.txt ...
# Reading 03559.txt ...
# Reading 03560.txt ...
# Occurrences in Berchse saldaote in IndiÃ« (1938) (03560.txt)
#
# Reading 03561.txt ...
# Reading 03562.txt ...
# Occurrences in "Over Unentse soldaten overzee : Den Vaderlant Ghetrouwe"" in Nederlands-Indie 1945-1950 /""" (03562.txt)
#
# Reading 03563.txt ...
# Reading 03564.txt ...
# Reading 03565.txt ...
# Occurrences in Oost-Java : gedenkboek der 4e Infanterie-Brigade (03565.txt)
#
# Reading 03566.txt ...
# Occurrences in Brieven uit Indie (03566.txt)
#
# Reading 03567.txt ...
# Reading 03568.txt ...
# Reading 03569.txt ...
# Reading 03570.txt ...
# Reading 03571.txt ...
# Occurrences in De jongens van 'Toedjoe Poeloe Doea' : herinneringsalbum van het Bataljon 3-14 R.I., 3e Infanterie Brigade Groep, 1 Divisie '7 December', West-Java 1946-1950 (03571.txt)
#
# Reading 03572.txt ...
# Occurrences in Tropen jaren : Cranendonckse jongens in Indie? en Nieuw-Guinea, 1945-1962 (03572.txt)
#
# Reading 03573.txt ...
# Reading 03574.txt ...
# Reading 03575.txt ...
# Reading 03576.txt ...
# Reading 03577.txt ...
# Occurrences in Varen door mijn herinneringen : het leven van dolle Dries (03577.txt)
#
# Reading 03578.txt ...
# Reading 03579.txt ...
# Occurrences in Pancrassers onder de wapenen in de tropen, 1946-1962 (03579.txt)
#
# Reading 03580.txt ...
# Occurrences in Pa, vertel 's over je tijd in IndiÃ«! : dagboekaantekeningen IndiÃ« 1946-1949 (03580.txt)
#
# Reading 03581.txt ...
# Reading 03582.txt ...
# Reading 03583.txt ...
# Reading 03584.txt ...
# Reading 03585.txt ...
# Occurrences in Indie?-gangers uit Ootmarsum vertellen! (03585.txt)
#
# Reading 03586.txt ...
# Reading 03587.txt ...
# Reading 03588.txt ...
# Reading 03589.txt ...
# Reading 03590.txt ...
# Reading 03591.txt ...
# Reading 03592.txt ...
# Reading 03593.txt ...
# Reading 03594.txt ...
# Reading 03595.txt ...
# Reading 03596.txt ...
# Reading 03597.txt ...
# Occurrences in Eerbetoon aan onze jongens in Oost-Indie?, 1945-1951 : gemeente Weerselo (03597.txt)
#
# Reading 03598.txt ...
# Reading 03599.txt ...
# Reading 03600.txt ...
# Reading 03601.txt ...
# Occurrences in Van Amersfoort naar Batavia' door 4-8 R.I. (03601.txt)
#
# Reading 03602.txt ...
# Reading 03603.txt ...
# Occurrences in Indie? 1947-1948 : een prachtig land in oorlog (03603.txt)
#
# Reading 03604.txt ...
# Reading 03605.txt ...
# Reading 03606.txt ...
# Reading 03607.txt ...
# Reading 03608.txt ...
# Reading 03609.txt ...
# Reading 03610.txt ...
# Reading 03611.txt ...
# Reading 03612.txt ...
# Reading 03613.txt ...
# Reading 03614.txt ...
# Reading 03615.txt ...
# Reading 03616.txt ...
# Reading 03617.txt ...
# Reading 03618.txt ...
# Occurrences in De kist : het levensverhaal van The? van de Locht. (03618.txt)
#
# Reading 03619.txt ...
# Reading 03620.txt ...
# Reading 03621.txt ...
# Reading 03622.txt ...
# Reading 03623.txt ...
# Reading 03624.txt ...
# Occurrences in Vertel nog eens over de oorlog : oorlogsherinneringen van een onderwijzer (1991) (03624.txt)
#
# Reading 03625.txt ...
# Reading 03626.txt ...
# Occurrences in Een stem uit het veld : herinneringen van de ritmeester-adjudant van generaal S.H. Spoor (1988) (03626.txt)
#
# Reading 03627.txt ...
# Reading 03628.txt ...
# Reading 03629.txt ...
# Reading 03630.txt ...
# Occurrences in Dagboek van een oorlogsvrijwilliger (1994) (03630.txt)
#
# Reading 03631.txt ...
# Reading 03632.txt ...
# Occurrences in 9 februari : vulneratus nec victus, gewond maar niet verslagen (03632.txt)
#
# Reading 03633.txt ...
# Occurrences in Doorbraak naar het onvoltooid verleden : autobiografie van een sergeant van het v.m. Koninklijk Nederlands Indisch Leger tijdens de Tweede Wereldoorlog tegen Japan (1995) (03633.txt)
#
# Reading 03634.txt ...
# Occurrences in Herinneringsboek der 14e Genie Veld Compagnie januari 1948 tot juni 1950 (03634.txt)
#
# Reading 03635.txt ...
# Reading 03636.txt ...
# Reading 03637.txt ...
# Occurrences in Zeg, Hollands soldaat... : gebaseerd op originele brieven en rapporten van Indie?-soldaten van het voormalige 425e Bataljon Infanterie in de periode 1949/1950 op Midden-Java (1995) (03637.txt)
#
# Reading 03638.txt ...
# Occurrences in Ons Indie? (03638.txt)
#
# Reading 03639.txt ...
# Occurrences in 5e Cie 4e Bataljon 11e Regt. Infanterie (1947) (03639.txt)
#
# Reading 03640.txt ...
# Occurrences in 3e Cie 4e Bataljon 11e Regt. Infanterie (1947) (03640.txt)
#
# Reading 03641.txt ...
# Occurrences in 1e Cie 4e Bataljon 11e Regt. Infanterie : uit het dagboek van een soldaat van de 1e Cie (1994) (03641.txt)
#
# Reading 03642.txt ...
# Reading 03643.txt ...
# Reading 03644.txt ...
# Reading 03645.txt ...
# Reading 03646.txt ...
# Reading 03647.txt ...
# Occurrences in Duizend dagen (1947) (03647.txt)
#
# Reading 03648.txt ...
# Occurrences in De verzwegen oorlog : dagboek van een hospik in IndiÃ« 1947-1950 (03648.txt)
#
# Reading 03649.txt ...
# Occurrences in IJsbloemen en witte velden : Ger V. en een spoor van geweld (1989) (03649.txt)
#
# Reading 03650.txt ...
# Reading 03651.txt ...
# Reading 03652.txt ...
# Reading 03653.txt ...
# Reading 03654.txt ...
# Reading 03655.txt ...
# Reading 03656.txt ...
# Reading 03657.txt ...
# Reading 03658.txt ...
# Reading 03659.txt ...
# Occurrences in Morotai : de bevrijding van de Grote Oost en Borneo (april 1944-april 1946) (1976) (03659.txt)
#
# Reading 03660.txt ...
# Reading 03661.txt ...
# Occurrences in Daar werd iets grootsch verricht', of Hoe het Koninkrijk der Nederlanden zijn grootste kolonie verloor (1980) (03661.txt)
#
# Reading 03662.txt ...
# Reading 03663.txt ...
# Reading 03664.txt ...
# Reading 03665.txt ...
# Reading 03666.txt ...
# Reading 03667.txt ...
# Reading 03668.txt ...
# Reading 03669.txt ...
# Reading 03670.txt ...
# Reading 03671.txt ...
# Reading 03672.txt ...
# Reading 03673.txt ...
# Reading 03674.txt ...
# Reading 03675.txt ...
# Reading 03676.txt ...
# Reading 03677.txt ...
# Reading 03678.txt ...
# Reading 03679.txt ...
# Reading 03680.txt ...
# Reading 03681.txt ...
# Reading 03682.txt ...
# Occurrences in Wij trokken naar Solo : een verzameling van schetsen en herinneringen uit de troep tot en met de overdracht van Solo (1949) (03682.txt)
#
# Reading 03683.txt ...
# Reading 03684.txt ...
# Occurrences in Toen de tjitjak riep : belevenissen van een bataljon oorlogsvrijwilligers in Nederlands Oost-Indie van 1946 tot 1948 (1983) (03684.txt)
#
# Reading 03685.txt ...
# Reading 03686.txt ...
# Reading 03687.txt ...
# Occurrences in Tussen goenoeng en guerilla (tussen berg en vrijheidsstrijd) (1986) (03687.txt)
#
# Reading 03688.txt ...
# Reading 03689.txt ...
# Reading 03690.txt ...
# Reading 03691.txt ...
# Reading 03692.txt ...
# Occurrences in Het vreemde leger (1985) (03692.txt)
#
# Reading 03693.txt ...
# Reading 03694.txt ...
# Reading 03695.txt ...
# Reading 03696.txt ...
# Reading 03697.txt ...
# Reading 03698.txt ...
# Reading 03699.txt ...
# Reading 03700.txt ...
# Occurrences in Wat gebeurt in IndonesiÃ«? (1948) (03700.txt)
#
# Reading 03701.txt ...
# Reading 03702.txt ...
# Reading 03703.txt ...
# Reading 03704.txt ...
# Reading 03705.txt ...
# Reading 03706.txt ...
# Reading 03707.txt ...
# Reading 03708.txt ...
# Reading 03709.txt ...
# Reading 03710.txt ...
# Reading 03711.txt ...
# Reading 03712.txt ...
# Reading 03713.txt ...
# Reading 03714.txt ...
# Reading 03715.txt ...
# Reading 03716.txt ...
# Reading 03717.txt ...
# Occurrences in Compiesboek : enkele belevenissen uit de Indie?-periode, opgetekend door de jongens van 2-V-10 R.I., 28 januari 1948-15 mei 1950. (1950) (03717.txt)
#
# Reading 03718.txt ...
# Reading 03719.txt ...
# Occurrences in Belevenissen van een K.N.I.L.-officier in de periode 1942-1950 : militaire ervaringen vo?o?r en bij politiÃ«le akties (1980) (03719.txt)
#
# Reading 03720.txt ...
# Reading 03721.txt ...
# Reading 03722.txt ...
# Reading 03723.txt ...
# Reading 03724.txt ...
# Reading 03725.txt ...
# Reading 03726.txt ...
# Reading 03727.txt ...
# Reading 03728.txt ...
# Occurrences in De heren worden bedankt : met het vergeten leger in Indie?, 1949-1950 (1986) (03728.txt)
#
# Reading 03729.txt ...
# Reading 03730.txt ...
# Reading 03731.txt ...
# Reading 03732.txt ...
# Reading 03733.txt ...
# Reading 03734.txt ...
# Reading 03735.txt ...
# Occurrences in Da?t was 423 : leven en werken van het 423 Bataljon in Oost-Java (1951) (03735.txt)
#
# Reading 03736.txt ...
# Reading 03737.txt ...
# Reading 03738.txt ...
# Reading 03739.txt ...
# Reading 03740.txt ...
# Reading 03741.txt ...
# Reading 03742.txt ...
# Occurrences in Met de T.N.I. op stap : de laatste patrouille van het vergeten leger (1991) (03742.txt)
#
# Reading 03743.txt ...
# Occurrences in Awas, pijp-pijp datang : gedenkboek geschreven door en voor de manschappen van 5-5 R.I. (1950) (03743.txt)
#
# Reading 03744.txt ...
# Reading 03745.txt ...
# Reading 03746.txt ...
# Reading 03747.txt ...
# Reading 03748.txt ...
# Reading 03749.txt ...
# Reading 03750.txt ...
# Reading 03751.txt ...
# Reading 03752.txt ...
# Occurrences in De geschiedenis van de 1e Infanterie Brigade Werkplaats 87 in Engeland, Nederland en Indie, 1945-1949 (1988) (03752.txt)
#
# Reading 03753.txt ...
# Occurrences in Ons dagboek 1946-1950 : 2e peloton, 10e genie veldcompagnie (1989) (03753.txt)
#
# Reading 03754.txt ...
# Reading 03755.txt ...
# Reading 03756.txt ...
# Reading 03757.txt ...
# Reading 03758.txt ...
# Reading 03759.txt ...
# Reading 03760.txt ...
# Reading 03761.txt ...
# Reading 03762.txt ...
# Occurrences in Zo was het : Gedenkboek 3-5-R.I. 1946-1950 (1950) (03762.txt)
#
# Reading 03763.txt ...
# Occurrences in 1e Bataljon, 5e Regiment Infanterie : gedenkboek 1945-1948. (1951) (03763.txt)
#
# Reading 03764.txt ...
# Reading 03765.txt ...
# Reading 03766.txt ...
# Reading 03767.txt ...
# Occurrences in Het Andjing Nica Bataljon (KNIL) in Nederlands-Indie? (1945-1950) (1999) (03767.txt)
#
# Reading 03768.txt ...
# Reading 03769.txt ...
# Reading 03770.txt ...
# Reading 03771.txt ...
# Reading 03772.txt ...
# Reading 03773.txt ...
# Reading 03774.txt ...
# Reading 03775.txt ...
# Reading 03776.txt ...
# Reading 03777.txt ...
# Occurrences in De geschiedenis van het 425e Bataljon Infanterie, de trekvogels : Indonesie? 1949-1950 (1983) (03777.txt)
#
# Reading 03778.txt ...
# Reading 03779.txt ...
# Occurrences in De hitte van de dag : onze soldaten in Indonesie? (03779.txt)
#
# Reading 03780.txt ...
# Occurrences in Met vlaggen van top : verrichtingen der Koninklijke marine in de Nederlandsch-Indische wateren voor herstel van orde en vrede van 1945 tot 1948 (03780.txt)
#
# Reading 03781.txt ...
# Reading 03782.txt ...
# Reading 03783.txt ...
# Reading 03784.txt ...
# Occurrences in Soldaat in Indie? : dagelijkse belevenissen (03784.txt)
#
# Reading 03785.txt ...
# Reading 03786.txt ...
# Reading 03787.txt ...
# Reading 03788.txt ...
# Reading 03789.txt ...
# Reading 03790.txt ...
# Reading 03791.txt ...
# Reading 03792.txt ...
# Reading 03793.txt ...
# Reading 03794.txt ...
# Reading 03795.txt ...
# Occurrences in De herinneringen blijven : Indonesie? 1945-1950 (03795.txt)
#
# Reading 03796.txt ...
# Reading 03797.txt ...
# Reading 03798.txt ...
# Reading 03799.txt ...
# Reading 03800.txt ...
# Reading 03801.txt ...
# Occurrences in Westerling, 'de eenling' (1982) (03801.txt)
#
# Reading 03802.txt ...
# Occurrences in Over een oorlog die niet nodig was : Indie?veteranen vertellen : dienstplichtige militairen uit Hem en Venhuizen in Nederlands-Indie? van 1945 tot 1950 (03802.txt)
#
# Reading 03803.txt ...
# Reading 03804.txt ...
# Reading 03805.txt ...
# Reading 03806.txt ...
# Reading 03807.txt ...
# Reading 03808.txt ...
# Reading 03809.txt ...
# Reading 03810.txt ...
# Reading 03811.txt ...
# Reading 03812.txt ...
# Occurrences in Dagboek van een dienstplichtig sergeant-majoor-administrateur : Mijn tropenjaren in dienst van de Majesteit 5 februari 1947 t/m 18 februari 1950 (03812.txt)
#
# Reading 03813.txt ...
# Reading 03814.txt ...
# Reading 03815.txt ...
# Reading 03816.txt ...
# Reading 03817.txt ...
# Occurrences in Demarcatielijn (1946) (03817.txt)
#
# Reading 03818.txt ...
# Reading 03819.txt ...
# Occurrences in Jongvolwassenen in de knel: dienstplicht in IndiÃ« 1946-1950: dagboekuittreksels (1992) (03819.txt)
#
# Reading 03820.txt ...
# Reading 03821.txt ...
# Reading 03822.txt ...
# Reading 03823.txt ...
# Occurrences in Djokja achter de horizon (1949) (03823.txt)
#
# Reading 03824.txt ...
# Reading 03825.txt ...
# Reading 03826.txt ...
# Reading 03827.txt ...
# Reading 03828.txt ...
# Reading 03829.txt ...
# Reading 03830.txt ...
# Reading 03831.txt ...
# Reading 03832.txt ...
# Occurrences in "De verhalen van de sobats van het 3e Bataljon Garderegiment ""Prinses Irene""" (2012) (03832.txt)
#
# Reading 03833.txt ...
# Reading 03834.txt ...
# Occurrences in Een verleden herleefd: IndiÃ« 1948-1950 (2006) (03834.txt)
#
# Reading 03835.txt ...
# Reading 03836.txt ...
# Reading 03837.txt ...
# Occurrences in Herinneringen van een gemobiliseerde Infanterist, Engeland - en IndiÃ«ganger 1939-1948 (1991) (03837.txt)
#
# Reading 03838.txt ...
# Occurrences in Brief aan een psycholoog: oorlogservaringen (2000) (03838.txt)
#
# Reading 03839.txt ...
# Occurrences in Er waren er die niet gingen: Vijftien eeuwen straf voor IndonesiÃ«-weigeraars (1995) (03839.txt)
#
# Reading 03840.txt ...
# Reading 03841.txt ...
# Reading 03842.txt ...
# Reading 03843.txt ...
# Reading 03844.txt ...
# Reading 03845.txt ...
# Occurrences in Het vergeten leger : het 425e bataljon infanterie (1984) (03845.txt)
#
# Reading 03846.txt ...
# Reading 03847.txt ...
# Reading 03848.txt ...
# Reading 03849.txt ...
# Occurrences in Het trommeltje. Herinneringen 1944-1949. Deel 1. (1997) (03849.txt)
#
# Reading 03850.txt ...
# Reading 03851.txt ...
# Reading 03852.txt ...
# Reading 03853.txt ...
# Reading 03854.txt ...
# Reading 03855.txt ...
# Reading 03856.txt ...
# Reading 03857.txt ...
# Reading 03860.txt ...
# Reading 03861.txt ...
# Reading 03863.txt ...
# Reading 03864.txt ...
# Reading 03865.txt ...
# Reading 03867.txt ...
# Reading 03868.txt ...
# Reading 03869.txt ...
# Reading 03870.txt ...
# Occurrences in 43e Hulpverbandplaatsafdeling 1949-1951 (1999) (03870.txt)
#
# Reading 03872.txt ...
# Reading 03873.txt ...
# Reading 03874.txt ...
# Reading 03875.txt ...
# Reading 03876.txt ...
# Reading 03877.txt ...
# Reading 03879.txt ...
# Reading 03880.txt ...
# Reading 03881.txt ...
# Reading 03882.txt ...
# Occurrences in Zinvol geweld? 17 november 1947-4 november 1950 (2012) (03882.txt)
#
# Reading 03891.txt ...
# Occurrences in Tussen Alcantara en Zuiderkruis. Een verhaal over de belevenissen van het IIIe (7e) Bataljon van het Oorlogsregiment Stoottroepen in het voormalig Nederlands Oost IndiÃ«. (1945) (03891.txt)
#
# Reading 03892.txt ...
# Reading 03893.txt ...
# Reading 03894.txt ...
# Reading 03895.txt ...
# Reading 03896.txt ...
# Reading 03897.txt ...
# Occurrences in Ach, wat is belangrijk (03897.txt)
#
# Reading 03913.txt ...
# Reading 03919.txt ...
# Reading 03920.txt ...
# Occurrences in Worsteling met het verleden. Levensverhaal van een Venlonaar. (2013) (03920.txt)
#
# Reading 03921.txt ...
# Reading 03922.txt ...
# Reading 03923.txt ...
# Reading 03924.txt ...
# Reading 03925.txt ...
# Reading 03926.txt ...
# Reading 03927.txt ...
# Occurrences in #### (03927.txt)
#
# Reading 03928.txt ...
# Reading 03929.txt ...
# Reading 03930.txt ...
# Occurrences in Soldaat overzee. (03930.txt)
#
# Reading 03931.txt ...
# Reading 03932.txt ...
# Reading 03934.txt ...
# Reading 03935.txt ...
# Occurrences in Kennemers, watermannen en rijstvogels (03935.txt)
#
# Reading 03936.txt ...
# Reading 03937.txt ...
# Reading 03938.txt ...
# Reading 03939.txt ...
# Reading 03940.txt ...
# Reading 03941.txt ...
# Occurrences in Het vergeten leger (1986) (03941.txt)
#
# Reading 03942.txt ...
# Reading 03943.txt ...
# Occurrences in Bandjir over Noord-Sumatra (03943.txt)
#
# Reading 03944.txt ...
# Occurrences in Bandjir over Noord-Sumatra (03944.txt)
#
# Reading 03945.txt ...
# Reading 03946.txt ...
# Reading 03947.txt ...
# Reading 03948.txt ...
# Reading 03949.txt ...
# Reading 03950.txt ...
# Reading 03951.txt ...
# Reading 03952.txt ...
# Reading 03953.txt ...
# Reading 03954.txt ...
# Reading 03955.txt ...
# Reading 03956.txt ...
# Reading 03957.txt ...
# Reading 03958.txt ...
# Reading 03959.txt ...
# Reading 03960.txt ...
# Reading 03961.txt ...
# Reading 03962.txt ...
# Reading 03963.txt ...
# Reading 03964.txt ...
# Reading 03965.txt ...
# Reading 03966.txt ...
# Reading 03967.txt ...
# Reading 03968.txt ...
# Reading 03969.txt ...
# Reading 03970.txt ...
# Reading 03971.txt ...
# Reading 03972.txt ...
# Reading 03973.txt ...
# Reading 03974.txt ...
# Reading 03975.txt ...
# Reading 03976.txt ...
# Reading 03977.txt ...
# Reading 03978.txt ...
# Reading 03979.txt ...
# Reading 03980.txt ...
# Reading 03981.txt ...
# Reading 03982.txt ...
# Occurrences in Soldaat overzee : Indonesie? zoals wij dat zagen! : een fotoboek (03982.txt)
#
# Reading 03983.txt ...
# Reading 03984.txt ...
# Occurrences in De medische geschiedenis van een infanterie-bataljon der Koninklijke Landmacht gedurende drie jaar actieve dienst op Java, 1946-1950 (03984.txt)
#
# Reading 03985.txt ...
# Reading 03986.txt ...
# Reading 03991.txt ...
# Occurrences in TabÃ© Java TabÃ© IndiÃ« (03991.txt)
#
# Reading 03992.txt ...
# Occurrences in """Loslaten, dat gaat niet meer""." (2017) (03992.txt)
#
# Reading 03993.txt ...
# Reading 03994.txt ...
# Occurrences in De witte karbouw : herinneringen aan een oorlog in de tropen (1992) (03994.txt)
#
# Reading 03995.txt ...
# Reading 03996.txt ...
# Occurrences in "Ons groot avontuur : met 2-14 R.I. Bataljon Zeeland"" naar IndiÃ« /""" (1948) (03996.txt)
#
# Reading 03997.txt ...
# Reading 03998.txt ...
# Reading 03999.txt ...
# Occurrences in De brutale reis : de eerste tocht naar een nieuwe wereld (03999.txt)
#
# Reading 04000.txt ...
# Reading 06001.txt ...
# Reading 06002.txt ...
# Occurrences in Bandjir over Noord-Sumatra (06002.txt)
#
# Reading 06003.txt ...
# Reading 06004.txt ...
# Reading 06005.txt ...
# Occurrences in Allen zwijgen (1983) (06005.txt)
#
# Reading 06006.txt ...
# Reading 06007.txt ...
# Occurrences in Gedenkboek 4-11-R.I. (1947) (06007.txt)
#
# Excel file saved as
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_12372/2020107175.py in <module>
#     101 df.to_excel("testcoocurence.xlsx")
#     102 print("Excel file saved as")
# --> 103 out.close()
#     104
#     105
#
# NameError: name 'out' is not defined

# %% [markdown]
# **Ofening 3: Ga, met behulp van de bovenstaande code, op zoek naar passages waarin twee relevante zoektermen in voorkomen. Pas de waarden van de variabelen `search_term1` en `search_term2` aan. Indien nodig kun je ook de waarde van `window` aanpassen.**
